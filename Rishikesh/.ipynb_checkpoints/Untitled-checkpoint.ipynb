# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score
import numpy as np
import pandas as pd
import os
import random
from pandas.plotting import register_matplotlib_converters
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
register_matplotlib_converters()

from statsmodels.tsa.vector_ar.var_model import VAR

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\platform\self_check.py in preload_check()
#      86         try:
# ---> 87           ctypes.WinDLL(build_info.cudnn_dll_name)
#      88         except OSError:
#
# ~\Anaconda3\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     355         if handle is None:
# --> 356             self._handle = _dlopen(self._name, mode)
#     357         else:
#
# OSError: [WinError 126] The specified module could not be found
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-82-29dab690f1d1> in <module>
#      20 from statsmodels.tsa.vector_ar.var_model import VAR
#      21
# ---> 22 import tensorflow as tf
#      23 from tensorflow.keras import backend as K
#      24 from tensorflow.keras.layers import *
#
# ~\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      26
#      27 # pylint: disable=g-bad-import-order
# ---> 28 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      29 from tensorflow.python.tools import module_util as _module_util
#      30
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      47 import numpy as np
#      48
# ---> 49 from tensorflow.python import pywrap_tensorflow
#      50
#      51 # Protocol buffers
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      28 # Perform pre-load sanity checks in order to produce a more actionable error
#      29 # than we get from an error during SWIG import.
# ---> 30 self_check.preload_check()
#      31
#      32 # pylint: disable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\platform\self_check.py in preload_check()
#      95               "necessary DLL by downloading cuDNN %s from this URL: "
#      96               "https://developer.nvidia.com/cudnn"
# ---> 97               % (build_info.cudnn_dll_name, build_info.cudnn_version_number))
#      98
#      99   else:
#
# ImportError: Could not find 'cudnn64_7.dll'. TensorFlow requires that this DLL be installed in a directory that is named in your %PATH% environment variable. Note that installing cuDNN is a separate step from installing CUDA, and this DLL is often found in a different directory from the CUDA DLLs. You may install the necessary DLL by downloading cuDNN 7 from this URL: https://developer.nvidia.com/cudnn

# %%
dataset = pd.read_excel("dataset_compiled_rishikesh_95-2020.xlsx",parse_dates=['Date'])

# %%
dataset.head()
# Out:
#         Date   pH  Temp  Alkanity     Ca    Mg   DO  BOD   Cl  TDS
# 0 1995-06-01  8.0  14.5       64.0  22.0  13.6  8.6  1.4  6.0  NaN
# 1 1995-07-01  8.1  18.5       56.0  22.0  12.5  8.3  1.3  5.0  NaN
# 2 1995-08-01  7.9  18.5       48.0  15.0   9.4  7.7  1.2  4.0  NaN
# 3 1995-09-01  8.1  18.0       40.0  12.0   7.3  7.7  1.2  3.0  NaN
# 4 1995-10-01  8.1  17.5       44.0  12.0   9.4  8.4  1.3  4.0  NaN

# %%
dataset.tail()
# Out:
#           Date    pH  Temp  Alkanity     Ca    Mg    DO  BOD    Cl   TDS
# 296 2020-02-01  7.72  17.0       62.0  60.0  28.0  10.8  1.0  13.0  62.0
# 297 2020-03-01  7.70  19.0       71.0  53.0  30.0  11.6  1.2   6.5  84.0
# 298 2020-04-01  7.80  19.0       60.0  45.0  25.0  10.6  0.6   7.5  55.0
# 299 2020-05-01  7.10  18.0       54.0  40.0  20.0  11.0  0.6   8.0  51.0
# 300 2020-06-01  7.55  19.0       60.0  32.0  26.0  10.6  0.4   6.0  64.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
# Date         301 non-null datetime64[ns]
# pH           301 non-null float64
# Temp         301 non-null float64
# Alkanity     282 non-null float64
# Ca           282 non-null float64
# Mg           282 non-null float64
# DO           301 non-null float64
# BOD          301 non-null float64
# Cl           282 non-null float64
# TDS          90 non-null float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 23.6 KB

# %%
dataset[dataset['TDS'].notnull()].head()
# Out:
#           Date   pH  Temp  Alkanity     Ca   Mg   DO  BOD   Cl    TDS
# 192 2011-06-01  8.0  18.0       34.0  10.0  8.4  7.5  1.5  6.8  100.0
# 193 2011-07-01  7.9  18.0       35.0  10.0  8.0  8.0  2.0  7.1   91.0
# 194 2011-08-01  7.7  19.5       34.0  13.0  9.5  8.0  1.4  6.8   91.0
# 195 2011-09-01  8.2  21.5       26.0  12.0  8.6  8.2  1.2  6.2   90.0
# 196 2011-10-01  8.7  21.0       25.0  11.0  8.3  8.4  1.1  6.0   89.0

# %% [markdown]
# TDS data only available from Jun 2011 onwards

# %%
dataset.describe()
# Out:
#                pH        Temp   Alkanity           Ca          Mg          DO  \
# count  301.000000  301.000000  282.000000  282.000000  282.000000  301.000000
# mean     7.938140   16.423256   60.914894   28.273050   15.884043    7.674419
# std      0.308177    3.499227   14.635300   22.517528    8.237251    1.427717
# min      7.020000    6.500000    4.000000    7.000000    2.600000    4.200000
# 25%      7.800000   14.000000   56.000000   17.000000   10.675000    6.700000
# 50%      8.000000   17.000000   64.000000   22.000000   14.600000    7.200000
# 75%      8.100000   19.000000   71.000000   31.000000   18.800000    8.600000
# max     10.000000   24.000000  112.000000  128.000000   40.000000   11.800000
#
#               BOD          Cl         TDS
# count  301.000000  282.000000   90.000000
# mean     1.166445    8.375532  101.700000
# std      0.236016    2.854915   30.603095
# min      0.400000    3.000000   51.000000
# 25%      1.000000    6.000000   80.250000
# 50%      1.100000    8.000000   92.000000
# 75%      1.200000   10.000000  111.500000
# max      3.300000   21.000000  220.000000

# %% [markdown]
# Alkalinity min value 4 might be an outlier

# %%
dataset.set_index('Date', inplace= True)

# %%
sns.heatmap(dataset.isnull() , cmap = 'viridis' , yticklabels = False)

# %%
dataset.columns  = ['pH', 'Temp', 'Alkanity', 'Ca', 'Mg', 'DO', 'BOD', 'Cl', 'TDS']

# %%
dat = (dataset.isnull().sum()).sort_values(ascending= False)
Missing_Data = pd.DataFrame({'Number of missing values' : dat})
Missing_Data
# Out:
#           Number of missing values
# TDS                            211
# Cl                              19
# Mg                              19
# Ca                              19
# Alkanity                        19
# BOD                              0
# DO                               0
# Temp                             0
# pH                               0

# %%
lis =  dataset.columns
for i in lis:
    plt.figure(figsize=(25, 10))
    plt.plot(dataset[i])
    plt.ylabel(i)
    plt.xlabel('Date')
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
dataset.drop('TDS', inplace =True, axis= 1 )
features = ['pH', 'Temp', 'Alkanity', 'Ca', 'Mg', 'DO', 'BOD', 'Cl']    #excluding TDS from input features

# %%
dataset[dataset['Mg'].isnull() & dataset['Temp'].notna()].index
# Out:
# DatetimeIndex(['2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01',
#                '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01',
#                '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01',
#                '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01',
#                '2016-10-01', '2016-11-01', '2016-12-01'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# Mg, Ca, Cl missing values Jun 2015 - dec 16 where temp and other values are non null

# %%
#interpolating values
dataset= dataset.interpolate(method='time')

# %%
lis =  features
for i in lis:
    plt.figure(figsize=(25, 10))
    plt.plot(dataset[i])
    plt.ylabel(i)
    plt.xlabel('Date')

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(dataset.corr(),annot=True, linewidths=1 ,cmap= 'viridis')

# %% [markdown]
# - Autocorrelations plots

# %%
for i in dataset:
    plot_acf(dataset[i], lags = 50)
    plt.title('ACF for %s' % i)
    plt.show()

# %% [markdown]
# Stationarity Tests

# %% [markdown]
# - AdFuller

# %%
from statsmodels.tsa.stattools import adfuller
#Ho: It is non stationary
#H1: It is stationary
non_stationary_ad_fuller  = []
def adfuller_test(values, i):
    result=adfuller(values)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("Time series has a unit root, indicating it is non-stationary ")
        non_stationary_ad_fuller.append(i)

# %%
for i in lis:
    print(i)
    adfuller_test(dataset[i],i)
# Out:
# pH
# ADF Test Statistic : -3.453681428127175
# p-value : 0.00925945187989421
# #Lags Used : 4
# Number of Observations Used : 296
# Reject the null hypothesis. Data has no unit root and is stationary
# Temp
# ADF Test Statistic : -2.334110000468838
# p-value : 0.16120264379807603
# #Lags Used : 14
# Number of Observations Used : 286
# Time series has a unit root, indicating it is non-stationary
# Alkanity
# ADF Test Statistic : -3.862841598796812
# p-value : 0.002325984276166398
# #Lags Used : 0
# Number of Observations Used : 300
# Reject the null hypothesis. Data has no unit root and is stationary
# Ca
# ADF Test Statistic : -2.81739533622896
# p-value : 0.055831609208295885
# #Lags Used : 12
# Number of Observations Used : 288
# Time series has a unit root, indicating it is non-stationary
# Mg
# ADF Test Statistic : -2.066778700118278
# p-value : 0.2580810997448269
# #Lags Used : 0
# Number of Observations Used : 300
# Time series has a unit root, indicating it is non-stationary
# DO
# ADF Test Statistic : -0.17718099484066308
# p-value : 0.9411874850122224
# #Lags Used : 16
# Number of Observations Used : 284
# Time series has a unit root, indicating it is non-stationary
# BOD
# ADF Test Statistic : -3.579195308911526
# p-value : 0.0061714541689199065
# #Lags Used : 4
# Number of Observations Used : 296
# Reject the null hypothesis. Data has no unit root and is stationary
# Cl
# ADF Test Statistic : -2.2676873911528994
# p-value : 0.18260125191933163
# #Lags Used : 12
# Number of Observations Used : 288
# Time series has a unit root, indicating it is non-stationary

# %%
non_stationary_ad_fuller
# Out:
# ['Temp', 'Ca', 'Mg', 'DO', 'Cl']

# %% [markdown]
# Dealing with non-stationary variables

# %%
dataset_differenced = dataset.diff().dropna()

# %%
for i in lis:
    print(i)
    adfuller_test(dataset_differenced[i],i)
# Out:
# pH
# ADF Test Statistic : -8.145620052665933
# p-value : 1.0007708435251035e-12
# #Lags Used : 9
# Number of Observations Used : 290
# Reject the null hypothesis. Data has no unit root and is stationary
# Temp
# ADF Test Statistic : -5.557148798513792
# p-value : 1.571524446570196e-06
# #Lags Used : 13
# Number of Observations Used : 286
# Reject the null hypothesis. Data has no unit root and is stationary
# Alkanity
# ADF Test Statistic : -9.483303210137336
# p-value : 3.821309866101969e-16
# #Lags Used : 5
# Number of Observations Used : 294
# Reject the null hypothesis. Data has no unit root and is stationary
# Ca
# ADF Test Statistic : -7.068990137328337
# p-value : 4.993968037138964e-10
# #Lags Used : 11
# Number of Observations Used : 288
# Reject the null hypothesis. Data has no unit root and is stationary
# Mg
# ADF Test Statistic : -8.89931381802978
# p-value : 1.1831744148623381e-14
# #Lags Used : 5
# Number of Observations Used : 294
# Reject the null hypothesis. Data has no unit root and is stationary
# DO
# ADF Test Statistic : -4.018254302231905
# p-value : 0.0013178855539996291
# #Lags Used : 15
# Number of Observations Used : 284
# Reject the null hypothesis. Data has no unit root and is stationary
# BOD
# ADF Test Statistic : -10.804111702377845
# p-value : 1.9833546348646748e-19
# #Lags Used : 5
# Number of Observations Used : 294
# Reject the null hypothesis. Data has no unit root and is stationary
# Cl
# ADF Test Statistic : -6.6578207908456
# p-value : 4.932971825743925e-09
# #Lags Used : 11
# Number of Observations Used : 288
# Reject the null hypothesis. Data has no unit root and is stationary

# %% [markdown]
# - All variables stationary now

# %%
lis =  features
for i in lis:
    plt.figure(figsize=(25, 10))
    plt.plot(dataset_differenced[i])
    plt.ylabel(i)
    plt.xlabel('Date')

# %% [markdown]
# #### Checking persistent models performance

# %%
from math import sqrt
def persistence(train, test , label):
    # walk-forward validation
    history = [x for x in train]
    predictions = list()
    for i in range(len(test)):
        # make prediction
        predictions.append(history[-1]) #persistence based on one day prior predictions
        # observation
        history.append(test[i])
     # line plot of observed vs predicted
    plt.plot(test, label = 'test')
    plt.plot(predictions , label = 'predictions')
    plt.title(label)
    plt.legend(loc = 'best')
    plt.show()
    # report performance
    rmse = sqrt(mean_squared_error(test, predictions))
    r2 = r2_score(test,predictions)
    print('RMSE: %.3f' % rmse)
    print('R2 score : %.3f' %r2)

# %%
for i in lis:
    X = dataset_differenced[i].values
    train, test = X[:-20], X[-20:]
    persistence(train,test,i)
# Out:
# RMSE: 0.643
# R2 score : -2.331
# RMSE: 2.086
# R2 score : -1.489
# RMSE: 10.770
# R2 score : -1.781
# RMSE: 6.899
# R2 score : -0.673
# RMSE: 5.450
# R2 score : -1.248
# RMSE: 1.220
# R2 score : -2.224
# RMSE: 0.385
# R2 score : -1.273
# RMSE: 3.339
# R2 score : -1.672

# %% [markdown]
# Note - Take inverse transform before interpreting results

# %%
pd.plotting.lag_plot(dataset)

# %% [markdown]
# train test split

# %%
n_obs=20
X_train, X_test = dataset[0:-n_obs], dataset[-n_obs:]
print(X_train.shape, X_test.shape)
# Out:
# (286, 8) (15, 8)

# %% [markdown]
# Applying differencing only on train data

# %%
transformed_data = X_train.diff().dropna()

# %%
#LAG order selection
model = VAR(endog=transformed_data)
res = model.select_order(30)
res.summary()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# choosing lag = 30

# %% [markdown]
# VAR model

# %%
from statsmodels.tsa.api import VAR
model = VAR(endog = transformed_data)
results = model.fit(maxlags=30, ic='aic')
results.summary()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 04, Sep, 2020
# Time:                     02:36:15
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    17.5982
# Nobs:                     255.000    HQIC:                   1.59334
# Log likelihood:           203.379    FPE:                    69.5469
# AIC:                     -9.17658    Det(Omega_mle):        0.339426
# --------------------------------------------------------------------
# Results for equation pH
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const               -0
# L29.Mg              -0.169026         0.147101           -1.149           0.251
# L29.DO              -0.182926         0.558822           -0.327           0.743
# L29.BOD              0.534900         2.094648            0.255           0.798
# L29.Cl              -0.378617         0.222111           -1.705           0.088
# L30.pH               2.107566         1.772463            1.189           0.234
# L30.Temp             0.029800         0.161276            0.185           0.853
# L30.Alkanity        -0.048371         0.044696           -1.082           0.279
# L30.Ca              -0.006034         0.028450           -0.212           0.832
# L30.Mg              -0.110679         0.159362           -0.695           0.487
# L30.DO              -0.750847         0.615070           -1.221           0.222
# L30.BOD              0.388689         1.944509            0.200           0.842
# L30.Cl               0.511950         0.228450            2.241           0.025
# ===============================================================================
#
# Correlation matrix of residuals
#                   pH      Temp  Alkanity        Ca        Mg        DO       BOD        Cl
# pH          1.000000  0.297384 -0.006887  0.272847 -0.077017 -0.420054 -0.105634 -0.342797
# Temp        0.297384  1.000000 -0.380228 -0.029185  0.389401 -0.192061  0.208372 -0.330085
# Alkanity   -0.006887 -0.380228  1.000000  0.271056 -0.011715  0.137485  0.040547  0.299768
# Ca          0.272847 -0.029185  0.271056  1.000000  0.293008  0.019273  0.023715 -0.480752
# Mg         -0.077017  0.389401 -0.011715  0.293008  1.000000 -0.123601 -0.050980 -0.293333
# DO         -0.420054 -0.192061  0.137485  0.019273 -0.123601  1.000000  0.334623 -0.121120
# BOD        -0.105634  0.208372  0.040547  0.023715 -0.050980  0.334623  1.000000 -0.173986
# Cl         -0.342797 -0.330085  0.299768 -0.480752 -0.293333 -0.121120 -0.173986  1.000000

# %% [markdown]
# ##### Forecasting

# %%
lag_order = 30
# Input data for forecasting
input_data = transformed_data.values[-lag_order:]
# forecasting
pred = results.forecast(y=input_data, steps=15)
pred = (pd.DataFrame(pred, index=X_test.index, columns=X_test.columns + '_pred'))

# %% [markdown]
# #### Inverse Transform

# %%
# inverting transformation
def invert_transformation(X_train, pred_df):
    forecast = pred.copy()
    columns = X_train.columns
    for col in columns:
        forecast[str(col)+'_pred'] = X_train[col].iloc[-1] + forecast[str(col)+'_pred'].cumsum()
    return forecast
output = invert_transformation(X_train, pred)

# %%
output
# Out:
#              pH_pred  Temp_pred  Alkanity_pred    Ca_pred    Mg_pred  \
# Date
# 2019-04-01  7.617065  18.792767      65.246831  41.256496  30.125885
# 2019-05-01  7.668069  19.484731      63.339078  39.587310  29.859376
# 2019-06-01  7.650416  18.838752      61.610687  42.001473  29.577807
# 2019-07-01  7.632265  18.072524      63.308315  41.085418  29.805817
# 2019-08-01  7.609239  17.505692      64.083724  41.134631  29.907103
# 2019-09-01  7.614996  17.173318      64.961731  41.010671  30.174278
# 2019-10-01  7.648092  17.477393      65.301712  41.487826  30.374500
# 2019-11-01  7.631639  17.650292      65.280508  41.817362  30.531365
# 2019-12-01  7.627276  17.920206      64.935961  41.985963  30.635534
# 2020-01-01  7.617637  17.996386      64.967275  42.071727  30.642034
# 2020-02-01  7.615246  17.965404      64.887020  41.982969  30.632821
# 2020-03-01  7.615494  17.997574      64.794868  42.030294  30.652975
# 2020-04-01  7.616516  18.011849      64.834205  42.061460  30.691005
# 2020-05-01  7.615949  18.024291      64.898463  42.164360  30.768396
# 2020-06-01  7.614208  17.988010      65.013924  42.300408  30.855399
#
#              DO_pred  BOD_pred   Cl_pred
# Date
# 2019-04-01  9.727583  1.041168  3.622912
# 2019-05-01  9.722665  1.000521  3.235386
# 2019-06-01  9.723090  1.031272  3.168542
# 2019-07-01  9.877387  1.027677  3.223405
# 2019-08-01  9.875002  1.010950  3.512488
# 2019-09-01  9.941122  1.025702  3.661789
# 2019-10-01  9.994313  1.016437  3.797337
# 2019-11-01  9.980745  1.012649  3.857245
# 2019-12-01  9.986065  1.020029  3.857994
# 2020-01-01  9.945455  1.016364  3.811554
# 2020-02-01  9.914134  1.013998  3.715175
# 2020-03-01  9.915970  1.014101  3.643121
# 2020-04-01  9.921558  1.010228  3.596078
# 2020-05-01  9.943075  1.010535  3.600965
# 2020-06-01  9.961912  1.011184  3.622837

# %%
for i in lis:
        plt.plot(X_test[i] , label = "Actual")
        plt.plot(output[i + '_pred'], label = "Predicted")
        plt.title(i)
        plt.legend(loc = 'best')
        plt.show()

# %% [markdown]
# #### Granger Causality test

# %% [markdown]
# Granger Causality tests try to determine if one variable(x1) can be used as a predictor of another variable(x2) where the past values of that another variable may or may not help

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=4

test = 'ssr-chi2test'

def grangers_causality_matrix(data, variables, test = 'ssr_chi2test', verbose=False):
    dataset = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in dataset.columns:
        for r in dataset.index:
            test_result = grangercausalitytests(transformed_data[[r,c]], maxlag=maxlag, verbose=False) 
        #Check if time series in the second column Granger causes the time series in the first column
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')

            min_p_value = np.min(p_values)
            dataset.loc[r,c] = min_p_value

    dataset.columns = [var +'_x' for var in variables]

    dataset.index = [var + '_y' for var in variables]

    return dataset

grangers_causality_matrix(dataset, variables = dataset.columns)
# Out:
#               pH_x  Temp_x  Alkanity_x    Ca_x    Mg_x    DO_x   BOD_x    Cl_x
# pH_y        1.0000  0.4211      0.0046  0.5989  0.2408  0.5942  0.0408  0.1267
# Temp_y      0.2775  1.0000      0.0243  0.4648  0.0411  0.0000  0.2817  0.0274
# Alkanity_y  0.0000  0.1576      1.0000  0.2735  0.1338  0.2768  0.0066  0.0127
# Ca_y        0.7787  0.2862      0.7870  1.0000  0.0351  0.5179  0.0062  0.8159
# Mg_y        0.5327  0.0148      0.5841  0.7814  1.0000  0.1305  0.0691  0.0840
# DO_y        0.0032  0.0005      0.0243  0.3663  0.2176  1.0000  0.0000  0.1851
# BOD_y       0.1538  0.7672      0.4758  0.0414  0.4030  0.0047  1.0000  0.0167
# Cl_y        0.0775  0.0000      0.4981  0.4222  0.1803  0.0769  0.1290  1.0000

# %% [markdown]
# #### Combining VAR with LSTM

# %%
def autocor_pred(real, pred, lag=1):
    return pearsonr(real[:-lag], pred[lag:])[0]


seq_length = 30

def get_model():
    
    opt = Adam()
    
    inp = Input(shape=(seq_length, 18))
    
    x = LSTM(64)(inp)
    x = Dropout(0.5)(x)
    x = Dense(32, activation='relu')(x)
    x = Dropout(0.5)(x)
    
    out = Dense(9)(x)
    
    model = Model(inp, out)
    model.compile(optimizer=opt, loss='mse')
    
    return model
